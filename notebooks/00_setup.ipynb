# %%
import sys
import os
import config

# Add the notebook's directory to the Python path
sys.path.append(os.getcwd())

# %%
# Import the fetch_raw_files function from your helper script
from FGT_data_helper import fetch_raw_files
from pandas
# Set your subject ID and task definition
IBBID = 'A3122'  # Replace with your actual subject ID
TASKDEF = 'audio_base'  # Replace with your actual task definition

# Fetch the raw MEG and behavioral data
raw, DF = fetch_raw_files(IBBID, TASKDEF)

# Display the MEG object and the first few rows of the behavioral DataFrame
print(raw)
if DF is not None:
    display(DF.head())
else:
    print("No behavioral data found.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Import the fetch_raw_files function from your helper script
# ----> 2 from FGT_data_helper import fetch_raw_files
#       4 # Set your subject ID and task definition
#       5 IBBID = 'A3122'  # Replace with your actual subject ID
#
# ModuleNotFoundError: No module named 'FGT_data_helper'
