# %% [markdown]
# # Data Exploration
#
# Interactive exploration of FGCM MEG data.

# %%
import sys
sys.path.insert(0, '..')

from dfgt import io, config
from dfgt.utils import get_valid_subjects

import mne
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
subjects = get_valid_subjects()
print(f'Total subjects: {len(subjects)}')

# %%
raw = io.load_raw_ctf('C01', 'audio_base')
raw.info

# %%
raw.plot(duration=10, n_channels=30);
